# %%
#import libraries
import pandas as pd #pandas for data frame
import numpy as np #numpy for matrix manipulation
import matplotlib.pyplot as plt #matplotlib for plotting and data visualization
import matplotlib
matplotlib.rcParams.update({'font.size': 12})

# %%
df = pd.read_csv('bike path/weather.csv')

# %%
print(df.columns)
# Out:
# Index(['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f',
#        'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f',
#        'max_humidity', 'mean_humidity', 'min_humidity',
#        'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches',
#        'min_sea_level_pressure_inches', 'max_visibility_miles',
#        'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph',
#        'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches',
#        'cloud_cover', 'events', 'wind_dir_degrees', 'zip_code'],
#       dtype='object')

# %%
df.sort_values(by='date', inplace=True)
df['date'] = pd.to_datetime(df['date'], infer_datetime_format = True)
df
# Out:
#            date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 309  2014-01-01               55.0                47.0               39.0
# 493  2014-01-01               59.0                48.0               36.0
# 125  2014-01-01               56.0                49.0               41.0
# 861  2014-01-01               62.0                49.0               35.0
# 677  2014-01-01               59.0                46.0               34.0
# 3422 2015-01-01               53.0                42.0               30.0
# 1962 2015-01-01               56.0                47.0               38.0
# 3057 2015-01-01               54.0                43.0               32.0
# 2692 2015-01-01               57.0                45.0               33.0
# 2327 2015-01-01               55.0                46.0               37.0
# 3787 2016-01-01               52.0                44.0               35.0
# 5251 2016-01-01               51.0                42.0               33.0
# ...
